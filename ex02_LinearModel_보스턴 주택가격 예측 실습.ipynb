# %%
import warnings
warnings.filterwarnings('ignore')    # 학습과정에서 발생하는 경고창을 무시하는 코드

# %% [markdown]
# ## 1.문제정의
# - 보스턴 주택 가격 데이터를 사용하여 주택 가격을 예측해보자
# - 회귀모델
# - LinearRegression, SGDRegressor

# %% [markdown]
# ## 2. 데이터 수집

# %%
import pandas as pd
boston_data = pd.read_csv('boston_house.csv')
boston_data.head(1)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE   DIS  RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.09  1.0  296.0     15.3
#
#        B  LSTAT  MEDV
# 0  396.9   4.98  24.0

# %%
X = boston_data.drop('MEDV', axis = True)   # 문제데이터
y = boston_data['MEDV']  # 답데이터

# 분리하고나면 항상 크기 확인하기
print(X.shape, y.shape)
# Out:
# (506, 13) (506,)

# %%
y.name = 'PRICE'

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: PRICE, Length: 506, dtype: float64

# %%
X.info()   # ✨문제데이터는 항상 숫자 형태로 생겨야한다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %% [markdown]
# ## 3. 데이터전처리
# - 보스턴 집값 데이터는 학습용 데이터이기 때문에 전처리가 필요없다.

# %% [markdown]
# ## 4. 탐색적 데이터 분석(EDA)
# ### 상관관계 분석
# - 컬럼간의 선형도(상관도)를 확인

# %%
boston_data.corr()    # correlation(상관관계)
# 상관계수(-1 ~ 1) : -1과 1에 가까울수록 두 컬럼이 관계가 깊다, 0에 가까울수록 관계가 없다.
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %% [markdown]
# | 영어 컬럼명  | 한글 번역                                      |
# | ------- | ------------------------------------------ |
# | CRIM    | 범죄율 (인구 1인당 도시 범죄율)                        |
# | ZN      | 25,000 평방피트를 초과하는 주거지역 비율                  |
# | INDUS   | 비소매 상업지역 면적 비율                             |
# | CHAS    | 찰스강 인접 여부 (1: 인접, 0: 비인접)                  |
# | NOX     | 대기 오염 농도 (산화질소 농도)                         |
# | RM      | 주택당 평균 방 개수                                |
# | AGE     | 1940년 이전에 건축된 주택 비율                        |
# | DIS     | 5개 보스턴 고용센터까지의 거리 (가중치 포함 거리)              |
# | RAD     | 방사형 고속도로 접근성 지수                            |
# | TAX     | 재산세율 (10,000달러당 세금)                        |
# | PTRATIO | 학생-교사 비율                                   |
# | B       | 흑인 인구 비율 지수 (1000(Bk - 0.63)^2, Bk는 흑인 비율) |
# | LSTAT   | 하위 계층 비율 (인구 중 사회경제적으로 낮은 비율)              |
# | MEDV    | 주택 가격의 중앙값 (단위: \$1,000)                   |

# %% [markdown]
# ## 5. 모델 선택 및 하이퍼파라미터 튜닝

# %%
# 수학적 공식을 이용한 해석적 모델(Linear Regression)
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
# 경사하강법
from sklearn.linear_model import SGDRegressor
sgd_model = SGDRegressor(eta0 = 0.01 , verbose = 1)

# %% [markdown]
# ### 5-1. 훈련데이터와 평가데이터로 분리
# - 학습지 7 : 시험지 3

# %%
# 랜덤샘플링 -> 전체 데이터를 7:3 비율로 섞어서 분류해주는 도구
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0
# Total training time: 0.00 seconds.
# -- Epoch 85
# Norm: 852783680656.24, NNZs: 13, Bias: 38361949217.537880, T: 30090, Avg. loss: 12599516623600072868967219200.000000
# Total training time: 0.00 seconds.
# -- Epoch 86
# Norm: 1106026163312.85, NNZs: 13, Bias: 42909442843.897926, T: 30444, Avg. loss: 12088048058948895749491916800.000000
# Total training time: 0.00 seconds.
# -- Epoch 87
# Norm: 1074444017178.53, NNZs: 13, Bias: 40452466415.792709, T: 30798, Avg. loss: 12135431492321565840878075904.000000
# Total training time: 0.00 seconds.
# -- Epoch 88
# Norm: 844203183157.62, NNZs: 13, Bias: 40455385171.466042, T: 31152, Avg. loss: 12289852461278208143038349312.000000
# Total training time: 0.00 seconds.
# -- Epoch 89
# Norm: 798816225940.86, NNZs: 13, Bias: 35322159573.823059, T: 31506, Avg. loss: 11852305546679303147005935616.000000
# Total training time: 0.00 seconds.
# -- Epoch 90
# Norm: 1005262337959.09, NNZs: 13, Bias: 39953350114.639450, T: 31860, Avg. loss: 11502983102629478145489633280.000000
# Total training time: 0.00 seconds.
# -- Epoch 91
# Norm: 829182308240.17, NNZs: 13, Bias: 38454593930.409393, T: 32214, Avg. loss: 11730357511159576771174596608.000000
# Total training time: 0.00 seconds.
# -- Epoch 92
# Norm: 867028244956.17, NNZs: 13, Bias: 37566007113.001724, T: 32568, Avg. loss: 12171515169744609899704221696.000000
# Total training time: 0.00 seconds.
# -- Epoch 93
# Norm: 672396970821.09, NNZs: 13, Bias: 39241166855.490440, T: 32922, Avg. loss: 11690389864624385053339680768.000000
# Total training time: 0.00 seconds.
# -- Epoch 94
# Norm: 819707997930.70, NNZs: 13, Bias: 32617939015.480091, T: 33276, Avg. loss: 11716989670325318168562630656.000000
# Total training time: 0.00 seconds.
# -- Epoch 95
# Norm: 857922449780.72, NNZs: 13, Bias: 35946480928.154732, T: 33630, Avg. loss: 11630370912535196732582002688.000000
# Total training time: 0.00 seconds.
# Convergence after 95 epochs took 0.00 seconds
# SGDRegressor(verbose=1)

# %% [markdown]
# ## 7. 예측(평가)

# %%
linear_model.score(X_train, y_train)
# Out:
# 0.7611598772034454

# %%
linear_model.score(X_test, y_test)
# Out:
# 0.6771696999851695

# %%
sgd_model.score(X_train, y_train)
# Out:
# -3.1525591224227085e+26

# %%
sgd_model.score(X_test, y_test)
# Out:
# -2.761062742872578e+26

# %% [markdown]
# ### 특성확장
#  - linear 모델의 성능이 굉장히 좋지 않게 나오고 있다
#  - 이유는 특성의 숫자가 적기 때문 -> 해결하기 위해 특성확장(특성곱)을 해보자

# %%
col = X.columns
col
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
# 1. 전체 컬럼을 순서대로 꺼내오는 for문
for i in range(col.size):
    # 2. 곱해지는 컬럼을 정하는 for문
    for j in range(i, col.size):
        # i * j = i * j
        X[col[i]+"*"+col[j]] = X[col[i]] * X[col[j]]

# %%
X.shape
# Out:
# (506, 104)

# %%
X.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  ...  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0  ...
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0  ...
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0  ...
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0  ...
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0  ...
#
#    TAX*TAX  TAX*PTRATIO      TAX*B  TAX*LSTAT  PTRATIO*PTRATIO  PTRATIO*B  \
# 0  87616.0       4528.8  117482.40    1474.08           234.09   6072.570
# 1  58564.0       4307.6   96049.80    2211.88           316.84   7064.820
# 2  58564.0       4307.6   95064.86     975.26           316.84   6992.374
# 3  49284.0       4151.4   87607.86     652.68           349.69   7379.581
# 4  49284.0       4151.4   88111.80    1183.26           349.69   7422.030
#
#    PTRATIO*LSTAT          B*B    B*LSTAT  LSTAT*LSTAT
# 0         76.194  157529.6100  1976.5620      24.8004
# 1        162.692  157529.6100  3627.6660      83.5396
# 2         71.734  154315.4089  1583.1049      16.2409
# 3         54.978  155732.8369  1160.2122       8.6436
# 4         99.671  157529.6100  2115.4770      28.4089
#
# [5 rows x 104 columns]

# %% [markdown]
# ### 데이터 스케일링
# - 주의사항 : 데이터 전처리 마지막에 사용
# - 결측치가 없는 상태에서 사용해야 하고 이상치는 있어도 됨

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
minmax.fit(X)   # 문제데이터인 X가 가지고 있는 범위로 학습
# Out:
# MinMaxScaler()

# %%
# 문제(X)의 기준으로 변환
X_trans = minmax.transform(X)
X_trans
# Out:
# array([[0.00000000e+00, 1.80000000e-01, 6.78152493e-02, ...,
#         1.00000000e+00, 1.30834308e-01, 1.51574863e-02],
#        [2.35922539e-04, 0.00000000e+00, 2.42302053e-01, ...,
#         1.00000000e+00, 2.40435074e-01, 5.59846615e-02],
#        [2.35697744e-04, 0.00000000e+00, 2.42302053e-01, ...,
#         9.79596197e-01, 1.04716511e-01, 9.20813385e-03],
#        ...,
#        [6.11892474e-04, 0.00000000e+00, 4.20454545e-01, ...,
#         1.00000000e+00, 1.48222891e-01, 2.00292898e-02],
#        [1.16072990e-03, 0.00000000e+00, 4.20454545e-01, ...,
#         9.82690814e-01, 1.68869818e-01, 2.71055404e-02],
#        [4.61841693e-04, 0.00000000e+00, 4.20454545e-01, ...,
#         1.00000000e+00, 2.07238689e-01, 4.10789948e-02]])

# %%
# 스케일링 된 X_trans 값으로 다시 분류
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_trans, y, 
                                                    test_size = 0.3, 
                                                    random_state = 5)

# %%
# 크기확인
print('문제 데이터 크기 :', X_train.shape, y_train.shape)
print('답 데이터 크기 :', X_test.shape, y_test.shape)
# Out:
# 문제 데이터 크기 : (354, 104) (354,)
# 답 데이터 크기 : (152, 104) (152,)

# %%
linear_model.fit(X_train, y_train)
sgd_model.fit(X_train, y_train)
# Out:
# -- Epoch 1
# Norm: 8.55, NNZs: 104, Bias: 3.246175, T: 354, Avg. loss: 43.823356
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 9.48, NNZs: 104, Bias: 3.763063, T: 708, Avg. loss: 26.783518
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 10.00, NNZs: 104, Bias: 4.056528, T: 1062, Avg. loss: 24.118312
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 10.51, NNZs: 104, Bias: 4.356280, T: 1416, Avg. loss: 21.847071
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 10.87, NNZs: 104, Bias: 4.527643, T: 1770, Avg. loss: 20.549263
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 11.31, NNZs: 104, Bias: 4.777588, T: 2124, Avg. loss: 19.285335
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 11.67, NNZs: 104, Bias: 4.969603, T: 2478, Avg. loss: 18.333521
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 11.97, NNZs: 104, Bias: 5.103468, T: 2832, Avg. loss: 17.510286
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 12.39, NNZs: 104, Bias: 5.336181, T: 3186, Avg. loss: 16.897439
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 12.71, NNZs: 104, Bias: 5.507113, T: 3540, Avg. loss: 16.273852
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 12.99, NNZs: 104, Bias: 5.641540, T: 3894, Avg. loss: 15.693791
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 13.23, NNZs: 104, Bias: 5.766253, T: 4248, Avg. loss: 15.333572
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 13.50, NNZs: 104, Bias: 5.904857, T: 4602, Avg. loss: 14.924046
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 13.71, NNZs: 104, Bias: 6.009417, T: 4956, Avg. loss: 14.521264
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 13.93, NNZs: 104, Bias: 6.133983, T: 5310, Avg. loss: 14.232272
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 14.14, NNZs: 104, Bias: 6.271141, T: 5664, Avg. loss: 13.924446
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 14.38, NNZs: 104, Bias: 6.431064, T: 6018, Avg. loss: 13.682039
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 14.54, NNZs: 104, Bias: 6.489380, T: 6372, Avg. loss: 13.474387
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 14.70, NNZs: 104, Bias: 6.586523, T: 6726, Avg. loss: 13.316567
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 14.93, NNZs: 104, Bias: 6.762404, T: 7080, Avg. loss: 12.906471
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 15.06, NNZs: 104, Bias: 6.832458, T: 7434, Avg. loss: 13.007413
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 15.21, NNZs: 104, Bias: 6.935405, T: 7788, Avg. loss: 12.810555
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 15.40, NNZs: 104, Bias: 7.063140, T: 8142, Avg. loss: 12.566167
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 15.47, NNZs: 104, Bias: 7.093373, T: 8496, Avg. loss: 12.551469
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 15.59, NNZs: 104, Bias: 7.166140, T: 8850, Avg. loss: 12.406815
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 15.75, NNZs: 104, Bias: 7.284155, T: 9204, Avg. loss: 12.307887
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 15.85, NNZs: 104, Bias: 7.345689, T: 9558, Avg. loss: 12.200258
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 15.95, NNZs: 104, Bias: 7.390076, T: 9912, Avg. loss: 12.032161
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 16.06, NNZs: 104, Bias: 7.483596, T: 10266, Avg. loss: 12.028144
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 16.17, NNZs: 104, Bias: 7.571283, T: 10620, Avg. loss: 11.911994
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 16.27, NNZs: 104, Bias: 7.639164, T: 10974, Avg. loss: 11.817300
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 16.36, NNZs: 104, Bias: 7.708879, T: 11328, Avg. loss: 11.747774
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 16.45, NNZs: 104, Bias: 7.783015, T: 11682, Avg. loss: 11.617175
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 16.55, NNZs: 104, Bias: 7.854100, T: 12036, Avg. loss: 11.554673
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 16.64, NNZs: 104, Bias: 7.938672, T: 12390, Avg. loss: 11.573252
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 16.70, NNZs: 104, Bias: 7.976407, T: 12744, Avg. loss: 11.451010
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 16.79, NNZs: 104, Bias: 8.061737, T: 13098, Avg. loss: 11.430372
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 16.90, NNZs: 104, Bias: 8.151037, T: 13452, Avg. loss: 11.358799
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 16.96, NNZs: 104, Bias: 8.199907, T: 13806, Avg. loss: 11.313416
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 17.04, NNZs: 104, Bias: 8.274033, T: 14160, Avg. loss: 11.231662
# Total training time: 0.01 seconds.
# -- Epoch 41
# Norm: 17.09, NNZs: 104, Bias: 8.311465, T: 14514, Avg. loss: 11.181817
# Total training time: 0.01 seconds.
# -- Epoch 42
# Norm: 17.17, NNZs: 104, Bias: 8.385484, T: 14868, Avg. loss: 11.099641
# Total training time: 0.01 seconds.
# -- Epoch 43
# Norm: 17.22, NNZs: 104, Bias: 8.410374, T: 15222, Avg. loss: 11.098019
# Total training time: 0.01 seconds.
# -- Epoch 44
# Norm: 17.29, NNZs: 104, Bias: 8.478623, T: 15576, Avg. loss: 11.026367
# Total training time: 0.01 seconds.
# -- Epoch 45
# Norm: 17.39, NNZs: 104, Bias: 8.579195, T: 15930, Avg. loss: 10.916136
# Total training time: 0.01 seconds.
# -- Epoch 46
# Norm: 17.40, NNZs: 104, Bias: 8.570114, T: 16284, Avg. loss: 10.954198
# Total training time: 0.01 seconds.
# -- Epoch 47
# Norm: 17.48, NNZs: 104, Bias: 8.656517, T: 16638, Avg. loss: 10.872440
# Total training time: 0.01 seconds.
# -- Epoch 48
# Norm: 17.53, NNZs: 104, Bias: 8.690680, T: 16992, Avg. loss: 10.843997
# Total training time: 0.01 seconds.
# -- Epoch 49
# Norm: 17.59, NNZs: 104, Bias: 8.753918, T: 17346, Avg. loss: 10.847781
# Total training time: 0.01 seconds.
# -- Epoch 50
# Norm: 17.65, NNZs: 104, Bias: 8.810356, T: 17700, Avg. loss: 10.791729
# Total training time: 0.01 seconds.
# -- Epoch 51
# Norm: 17.68, NNZs: 104, Bias: 8.829297, T: 18054, Avg. loss: 10.752309
# Total training time: 0.01 seconds.
# -- Epoch 52
# Norm: 17.74, NNZs: 104, Bias: 8.890418, T: 18408, Avg. loss: 10.735054
# Total training time: 0.01 seconds.
# -- Epoch 53
# Norm: 17.80, NNZs: 104, Bias: 8.936311, T: 18762, Avg. loss: 10.688199
# Total training time: 0.01 seconds.
# -- Epoch 54
# Norm: 17.84, NNZs: 104, Bias: 8.975310, T: 19116, Avg. loss: 10.651614
# Total training time: 0.01 seconds.
# -- Epoch 55
# Norm: 17.88, NNZs: 104, Bias: 9.026112, T: 19470, Avg. loss: 10.618405
# Total training time: 0.01 seconds.
# -- Epoch 56
# Norm: 17.91, NNZs: 104, Bias: 9.041202, T: 19824, Avg. loss: 10.551702
# Total training time: 0.01 seconds.
# -- Epoch 57
# Norm: 17.99, NNZs: 104, Bias: 9.130658, T: 20178, Avg. loss: 10.565232
# Total training time: 0.01 seconds.
# -- Epoch 58
# Norm: 18.03, NNZs: 104, Bias: 9.160695, T: 20532, Avg. loss: 10.543459
# Total training time: 0.01 seconds.
# -- Epoch 59
# Norm: 18.05, NNZs: 104, Bias: 9.169565, T: 20886, Avg. loss: 10.470126
# Total training time: 0.01 seconds.
# -- Epoch 60
# Norm: 18.10, NNZs: 104, Bias: 9.218698, T: 21240, Avg. loss: 10.506884
# Total training time: 0.01 seconds.
# -- Epoch 61
# Norm: 18.17, NNZs: 104, Bias: 9.307974, T: 21594, Avg. loss: 10.453043
# Total training time: 0.01 seconds.
# -- Epoch 62
# Norm: 18.21, NNZs: 104, Bias: 9.336690, T: 21948, Avg. loss: 10.433070
# Total training time: 0.01 seconds.
# -- Epoch 63
# Norm: 18.25, NNZs: 104, Bias: 9.387227, T: 22302, Avg. loss: 10.385353
# Total training time: 0.01 seconds.
# -- Epoch 64
# Norm: 18.29, NNZs: 104, Bias: 9.421042, T: 22656, Avg. loss: 10.307602
# Total training time: 0.01 seconds.
# -- Epoch 65
# Norm: 18.30, NNZs: 104, Bias: 9.421574, T: 23010, Avg. loss: 10.336231
# Total training time: 0.01 seconds.
# -- Epoch 66
# Norm: 18.37, NNZs: 104, Bias: 9.501685, T: 23364, Avg. loss: 10.310080
# Total training time: 0.01 seconds.
# -- Epoch 67
# Norm: 18.42, NNZs: 104, Bias: 9.560848, T: 23718, Avg. loss: 10.265892
# Total training time: 0.01 seconds.
# -- Epoch 68
# Norm: 18.43, NNZs: 104, Bias: 9.557160, T: 24072, Avg. loss: 10.232909
# Total training time: 0.01 seconds.
# -- Epoch 69
# Norm: 18.48, NNZs: 104, Bias: 9.615111, T: 24426, Avg. loss: 10.207650
# Total training time: 0.01 seconds.
# -- Epoch 70
# Norm: 18.51, NNZs: 104, Bias: 9.636031, T: 24780, Avg. loss: 10.235327
# Total training time: 0.01 seconds.
# -- Epoch 71
# Norm: 18.52, NNZs: 104, Bias: 9.642417, T: 25134, Avg. loss: 10.186837
# Total training time: 0.01 seconds.
# -- Epoch 72
# Norm: 18.58, NNZs: 104, Bias: 9.709075, T: 25488, Avg. loss: 10.179463
# Total training time: 0.01 seconds.
# -- Epoch 73
# Norm: 18.60, NNZs: 104, Bias: 9.718626, T: 25842, Avg. loss: 10.152473
# Total training time: 0.01 seconds.
# -- Epoch 74
# Norm: 18.63, NNZs: 104, Bias: 9.749623, T: 26196, Avg. loss: 10.096343
# Total training time: 0.01 seconds.
# -- Epoch 75
# Norm: 18.66, NNZs: 104, Bias: 9.777580, T: 26550, Avg. loss: 10.120736
# Total training time: 0.01 seconds.
# -- Epoch 76
# Norm: 18.71, NNZs: 104, Bias: 9.848135, T: 26904, Avg. loss: 10.038478
# Total training time: 0.01 seconds.
# -- Epoch 77
# Norm: 18.73, NNZs: 104, Bias: 9.866031, T: 27258, Avg. loss: 10.066237
# Total training time: 0.01 seconds.
# -- Epoch 78
# Norm: 18.77, NNZs: 104, Bias: 9.901031, T: 27612, Avg. loss: 10.065533
# Total training time: 0.01 seconds.
# -- Epoch 79
# Norm: 18.81, NNZs: 104, Bias: 9.937687, T: 27966, Avg. loss: 10.052037
# Total training time: 0.01 seconds.
# -- Epoch 80
# Norm: 18.82, NNZs: 104, Bias: 9.948667, T: 28320, Avg. loss: 10.002437
# Total training time: 0.01 seconds.
# -- Epoch 81
# Norm: 18.86, NNZs: 104, Bias: 9.991860, T: 28674, Avg. loss: 9.995838
# Total training time: 0.01 seconds.
# -- Epoch 82
# Norm: 18.90, NNZs: 104, Bias: 10.030847, T: 29028, Avg. loss: 9.987135
# Total training time: 0.01 seconds.
# -- Epoch 83
# Norm: 18.93, NNZs: 104, Bias: 10.060225, T: 29382, Avg. loss: 9.966347
# Total training time: 0.01 seconds.
# -- Epoch 84
# Norm: 18.96, NNZs: 104, Bias: 10.095530, T: 29736, Avg. loss: 9.929538
# Total training time: 0.01 seconds.
# -- Epoch 85
# Norm: 19.00, NNZs: 104, Bias: 10.140908, T: 30090, Avg. loss: 9.919178
# Total training time: 0.01 seconds.
# -- Epoch 86
# Norm: 19.02, NNZs: 104, Bias: 10.154129, T: 30444, Avg. loss: 9.905234
# Total training time: 0.01 seconds.
# -- Epoch 87
# Norm: 19.05, NNZs: 104, Bias: 10.188845, T: 30798, Avg. loss: 9.864916
# Total training time: 0.01 seconds.
# -- Epoch 88
# Norm: 19.07, NNZs: 104, Bias: 10.208181, T: 31152, Avg. loss: 9.877063
# Total training time: 0.01 seconds.
# -- Epoch 89
# Norm: 19.10, NNZs: 104, Bias: 10.222961, T: 31506, Avg. loss: 9.846618
# Total training time: 0.01 seconds.
# -- Epoch 90
# Norm: 19.13, NNZs: 104, Bias: 10.250586, T: 31860, Avg. loss: 9.831161
# Total training time: 0.01 seconds.
# -- Epoch 91
# Norm: 19.15, NNZs: 104, Bias: 10.274478, T: 32214, Avg. loss: 9.799673
# Total training time: 0.01 seconds.
# -- Epoch 92
# Norm: 19.19, NNZs: 104, Bias: 10.327021, T: 32568, Avg. loss: 9.812549
# Total training time: 0.01 seconds.
# -- Epoch 93
# Norm: 19.22, NNZs: 104, Bias: 10.348970, T: 32922, Avg. loss: 9.793141
# Total training time: 0.01 seconds.
# -- Epoch 94
# Norm: 19.26, NNZs: 104, Bias: 10.387764, T: 33276, Avg. loss: 9.782533
# Total training time: 0.01 seconds.
# -- Epoch 95
# Norm: 19.29, NNZs: 104, Bias: 10.428848, T: 33630, Avg. loss: 9.758266
# Total training time: 0.01 seconds.
# -- Epoch 96
# Norm: 19.29, NNZs: 104, Bias: 10.404932, T: 33984, Avg. loss: 9.705912
# Total training time: 0.01 seconds.
# -- Epoch 97
# Norm: 19.31, NNZs: 104, Bias: 10.408113, T: 34338, Avg. loss: 9.615337
# Total training time: 0.01 seconds.
# -- Epoch 98
# Norm: 19.35, NNZs: 104, Bias: 10.476478, T: 34692, Avg. loss: 9.791963
# Total training time: 0.01 seconds.
# -- Epoch 99
# Norm: 19.37, NNZs: 104, Bias: 10.478793, T: 35046, Avg. loss: 9.657982
# Total training time: 0.01 seconds.
# -- Epoch 100
# Norm: 19.41, NNZs: 104, Bias: 10.541819, T: 35400, Avg. loss: 9.681357
# Total training time: 0.01 seconds.
# -- Epoch 101
# Norm: 19.43, NNZs: 104, Bias: 10.547696, T: 35754, Avg. loss: 9.666869
# Total training time: 0.01 seconds.
# -- Epoch 102
# Norm: 19.46, NNZs: 104, Bias: 10.590202, T: 36108, Avg. loss: 9.664909
# Total training time: 0.01 seconds.
# Convergence after 102 epochs took 0.01 seconds
# SGDRegressor(verbose=1)

# %%
linear_model.score(X_train, y_train)
# Out:
# 0.933247168380447

# %%
linear_model.score(X_test, y_test)
# Out:
# 0.8093536758919457

# %%
sgd_model.score(X_train, y_train)
# Out:
# 0.7613621886770914

# %%
sgd_model.score(X_test, y_test)
# Out:
# 0.683149473718696

# %% [markdown]
# ### 규제를 적용시킨 모델
# - LinearRegression 모델이 가지고 있는 단점
#     - 모델이 잘못되었을 경우 수정이 안됨 -> 규제를 가해서 단점을 해소
#     - LinearRegression + L1규제 => Lasso
#     - LinearRegression + L2규제 => Ridge
# - 규제? 선형모델에서 가중치(w)에 영향을 주겠다 -> 모델에 개입하겠다

# %%
from sklearn.linear_model import Lasso, Ridge

# %% [markdown]
# #### Ridge 활용

# %%
# 하이퍼파라미터(alpha) 튜닝하는 함수 정의
def ridge_alpha(alpha):
    # ridge모델 생성
    ridge = Ridge(alpha = alpha)
    # 학습
    ridge.fit(X_train, y_train)
    # 결과확인
    print("훈련세트 점수 :", ridge.score(X_train, y_train))
    print("테스트세트 점수 :", ridge.score(X_test, y_test))

# %%
ridge_alpha(100)
# alpha값의 기본값은 1
# alpha 값을 증가 ==> 규제를 늘리겠다. 과대적합일 때 사용 -> 과소적합에 걸릴 위험이 있다
# alpha 값을 감소 ==> 규제를 줄이겠다. 과소적합일 때 사용 -> 과대적합에 걸릴 위험이 있다
# ==> alpha값이 0이면 규제를 안한 것과 같다 ==> LinearRegression과 같다.
# ridge 모델은 규제를 하든 안하든 전체 가중치를 사용 -> 모든 컬럼을 사용
# ㄴ> 전체 컬럼이 고루고루 중요할 때 사용
# Out:
# 훈련세트 점수 : 0.5867470593740554
# 테스트세트 점수 : 0.4908590961177438

# %% [markdown]
# #### Lasso 활용

# %%
import numpy as np

# %%
# 하이퍼파라미터(alpha) 튜닝하는 함수 정의
def lasso_alpha(alpha):
    # Lasso모델 생성
    lasso = Lasso(alpha = alpha)
    # 학습
    lasso.fit(X_train, y_train)
    # 결과확인
    print("훈련세트 점수 :", lasso.score(X_train, y_train))
    print("테스트세트 점수 :", lasso.score(X_test, y_test))
    # 사용한 특성의 수 확인
    print("사용한 특성의 수 :", np.sum(lasso.coef_ != 0))

# %%
lasso_alpha(0.0001)

# 규제를 늘릴수록 값이 잘 안나옴(과소적합)
# 규제를 줄일수록 값이 잘나옴(과대적합)
# 규제를 줄일수록 사용하는 컬럼의 개수가 늘어난다
# ㄴ> 컬럼의 개수를 모두 사용하면 LinearRegression 모델 사용했을 때와 거의 동일
# Lasso모델은 특정 특성이 중요하고 나머지 특성들의 중요도가 현저히 낮을 때 사용
# Out:
# 훈련세트 점수 : 0.9145337059961222
# 테스트세트 점수 : 0.8344026382098213
# 사용한 특성의 수 : 103
